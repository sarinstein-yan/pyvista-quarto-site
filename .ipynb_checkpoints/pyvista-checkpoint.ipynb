# %% [raw]
# ---
# title: "Interactive Plot by `PyVista` and `Plotly`"
# ---

# %%
import pyvista as pv
from pyvista import examples

# Load an example dataset
hills = examples.load_random_hills()

plotter = pv.Plotter(notebook=True, window_size=[800, 600])
plotter.add_mesh(hills, cmap='terrain', smooth_shading=True)
plotter.show(jupyter_backend='trame')
# Out:
# Widget(value='<iframe src="http://localhost:6200/index.html?ui=P_0x20e383b8950_7&reconnect=auto" class="pyvist…

# %%
import plotly.express as px
import plotly.io as pio
pio.renderers.default = "plotly_mimetype+notebook_connected"

df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", 
                 color="species", 
                 marginal_y="violin", 
                 marginal_x="box", 
                #  trendline="ols", 
                 template="simple_white")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
